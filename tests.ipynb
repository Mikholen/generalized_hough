# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import math
import random 

def generate_line_points(im_len, k, b, thickness=1):

    x = np.array([], 'int64')
    y = np.array([], 'int64')
    
    for i in range(0, thickness):
        
        x_i = np.arange(0, im_len, 1)
        y_i = (k * x_i + b + i).astype('int')
        points = [(x_i[j], y_i[j]) for j in range(im_len)]
        filtered_points = np.array(list(filter(lambda x: (x[1] >= 0) * (x[1] < im_len), points)))
        if (filtered_points.shape[0] != 0):
            x_i = filtered_points[:, 0]
            y_i = filtered_points[:, 1]
            x = np.hstack([x, x_i])
            y = np.hstack([y, y_i])
    return x, y

# %%
im_len = 244
x_points, y_points = generate_line_points(im_len, k = 2, b = 40, thickness=5)

x_points_2, y_points_2 = generate_line_points(im_len, k =-2, b =200, thickness=5)
img = np.zeros((im_len, im_len), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
img = 255 - img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray', alpha=0.5)
# plt.xticks([]), plt.yticks([])
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x110700710>)

# %%
im_len = 244
x_points, y_points = generate_line_points(im_len, k = 2, b = 40, thickness=5)

x_points_2, y_points_2 = generate_line_points(im_len, k = 2, b = 35, thickness=1)
img = np.zeros((im_len, im_len), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
img = 255 - img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray', alpha=1)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x1108bb0d0>)

# %%
im_len = 244
x_points, y_points = generate_line_points(im_len, k = 1.2, b = 0, thickness=5)

x_points_2, y_points_2 = generate_line_points(im_len, k = 3, b = 35, thickness=2)

x_points_3 = random.choices(range(244), k = 1000)
y_points_3 = random.choices(range(244), k = 1000)

img = np.zeros((im_len, im_len), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
img[x_points_3, y_points_3] = 255

img = 255 - img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray', alpha=1)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x117cb2f10>)

# %%
im_len = 244
x_points, y_points = generate_line_points(im_len, k = 2, b = 40, thickness=5)

x_points_2, y_points_2 = generate_line_points(im_len, k = 2.2, b = -100, thickness=1)
img = np.zeros((im_len, im_len), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
# img = img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray', alpha=1)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x1109ec950>)

# %%
im_len = 244
x_points, y_points = generate_line_points(im_len, k = 2, b = 0, thickness=1)

x_points_2, y_points_2 = generate_line_points(im_len, k = 3, b = 0, thickness=1)

x_points_3, y_points_3 = generate_line_points(im_len, k = 4, b = 0, thickness=1)

x_points_4, y_points_4 = generate_line_points(im_len, k = 5, b = 0, thickness=1)

img = np.zeros((im_len, im_len), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
img[x_points_3, y_points_3] = 255
img[x_points_4, y_points_4] = 255
# img = img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray', alpha=1)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x110915910>)

# %%
im_len = 5
x_points, y_points = generate_line_points(im_len, k = 2, b = 0, thickness=1)

x_points_2, y_points_2 = generate_line_points(im_len, k = 1, b = 1, thickness=1)
img = np.zeros((im_len, im_len), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
# img = img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray', alpha=1)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x1176826d0>)

# %%
def generate_line_points_ns(im_len, im_hight, k, b, thickness=1):

    x = np.array([], 'int64')
    y = np.array([], 'int64')
    
    for i in range(0, thickness):
        
        x_i = np.arange(0, im_len, 1)
        y_i = (k * x_i + b + i).astype('int')
        points = [(x_i[j], y_i[j]) for j in range(im_len)]
        filtered_points = np.array(list(filter(lambda x: (x[1] >= 0) * (x[1] < im_hight), points)))
        if (filtered_points.shape[0] != 0):
            x_i = filtered_points[:, 0]
            y_i = filtered_points[:, 1]
            x = np.hstack([x, x_i])
            y = np.hstack([y, y_i])
    return x, y

# %%
im_len = 300
im_hight = 100
x_points, y_points = generate_line_points_ns(im_len, im_hight, k = 2, b = 40, thickness=5)

x_points_2, y_points_2 = generate_line_points_ns(im_len, im_hight, k = 2, b = 0, thickness=5)
img = np.zeros((im_len, im_hight), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
img = 255 - img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray')
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x1176c0b90>)

# %%
im_len = 1000
im_hight = 20
x_points, y_points = generate_line_points_ns(im_len, im_hight, k = 0.1, b = 4, thickness=1)

x_points_2, y_points_2 = generate_line_points_ns(im_len, im_hight, k = 2, b = 0, thickness=2)
img = np.zeros((im_len, im_hight), dtype=np.uint8)
img[x_points, y_points] = 255
img[x_points_2, y_points_2] = 255
img = 255 - img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray')
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x1108fda90>)

# %%
im_len = 250
im_hight = 250
x_points, y_points = generate_line_points_ns(im_len, im_hight, k = 0, b = 100, thickness=3)

# x_points_2, y_points_2 = generate_line_points_ns(im_len, im_hight, k = 2, b = 0, thickness=2)
img = np.zeros((im_len, im_hight), dtype=np.uint8)
img[x_points, y_points] = 255
# img[x_points_2, y_points_2] = 255
img = 255 - img
plt.subplot(1, 2, 1), plt.imshow(img, cmap='gray')
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x11769b890>)
